# %% [markdown]
# These are where lecture notes will be written, describing what's happning in the code cells

# %% [markdown]
# There are different ways of changing fonts
# <font size ="4">
# Font size 4
# <font size ="10">
# font size 10

# %%
print ("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## Additional notes here

# %%
print ("Another python command")
# Out:
# Another python command
