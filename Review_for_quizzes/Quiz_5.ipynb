# %% [markdown]
# Lecture 24:
# .dtypes to see all column headings and data types
# .groupby
# zip lists
# computing means of columns
# .agg and .agg with dictionary
# chainging with .query .groupby and .agg
# aggregating and merging

# %% [markdown]
# Time series 1:
# .sort_values() to re order data
# to_datetime
# .query
# fill_between
