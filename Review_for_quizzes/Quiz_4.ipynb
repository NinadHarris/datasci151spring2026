# %% [markdown]
# Lecture 17:
# 1) How to load in a file
# 2) type() for a data frame
# 3) .head() -- shows first 5 rows or can do .head(7) etc
# 4) using cols by doing .values and "chaining"
# 5) grabbing columns from dataset
# 6) sorting by one variable ex: .sort_values(by="", ascending ="")
# 7) .iloc[]
# 8) adding variables (BMI ex) df_ht_wt["BMI"] = BMI
# 9) Random assignment group_no = np.random.choice([1, 2, 3, 4], size = num_rows)
# 10) .query ex high_mileagecars = carfeatures.query("mpg >= 25"). threshold = 25
# high_mileagecars = carfeatures.query("mpg >= @threshold")
# 11) `` Backticks for spaces ex: data_threshold_horsepower = new_dset.query("`miles per gallon` >= 20")
# 12) pd.unique() to extract a numpy array with some unique elements in that column
# 12) Compute two overlapping scatterplots
# 13)

# %% [markdown]
# Lecture 18a:
# Same as what's in lecture 17 lol

# %% [markdown]
# Lecture 18b: Merging
# 1) pd.merge to do: first extract columns you want from each data frame ex: results_short = df_results[["resultId", "raceId", "driverId", "points"]]
# races_short = df_races[["raceId", "year", "circuitId", "name"]]
# circuits_short = df_circuits[["circuitId", "name", "location", "country"]]
#
# then merge: df_merged = pd.merge(left = results_short, right = races_short, how = "left", on = "raceId")

# %% [markdown]
# 20a:
# 1) .query again, can use and/ or
# 2) pd.unique()
# 3) computing two overlapping plots (scattergrams and histograms)

# %% [markdown]
# 20b:Merging
# 1) pd.merge to merge datasets -- explains left, right, how, and on, also shows and additonal merge
# 2) can add suffixes= in pd.merge for better column naming

# %% [markdown]
# 20c:
# 1) Data types for each column by doing .dtypes
# 2) Showing ways to rename columns/variables ex .rename and inplace=
# 3) Cleaning data, replacing non numeric data using .isnumeric ex:
#
# df_non_number = df_survey.query("age.str.isnumeric() == False")
#
# non_numbers = pd.unique(df_non_number["age"])
# print(non_numbers)
#
# replacements = [21, 20, np.nan, 25, 19]
#
# df_survey["age"] = df_survey["age"].replace(non_numbers, replacements)
#
# df_survey["age"] = pd.to_numeric(df_survey["age"])
#
# print()
# print(df_survey["age"].mean())
