# %% [markdown]
# Lecture 8:
# Loops
# car_list = ["KIA", "Ferrari", "Ford", "Tesla"]
#
# for car_name in car_list:
#     print("Dear customer, we are writing about your " + car_name + " vehicle.")
#
# variable "car_name" takes the value of every item in the list "car_list", one by one.
#
# can unroll the loop
#
# Index = position number starting at 0
# using index:
# car_list = ["KIA", "Ferrari", "Ford", "Tesla"]
#
# index = 0
#
# for car_name in car_list:
#     print("Dear " + car_name + " customer, your position is " + str(index + 1) + " on the waitlist.")
#     index = index + 1
#
#
# car_list = ["KIA", "Ferrari", "Ford", "Tesla"]
#
# N = len(car_list) # number of elements
#
# for index in range(N):
#     # print(index)
#     print("Dear " + car_list[index] + " customer, your position is " + str(index + 1) +
#         " on the waitlist.")
#
# leng is # of items in car_list

# %% [markdown]
# Lecture 7:
# boolean variable and if else
# boolean:
# print(5 > 3)
# print(3 > 9)
# print(4 + 3 > 6)
#
# using "in"
# sentence = "The Federal Reserve makes forecasts about many economic outcomes"
# keyword = "economic"
# print(keyword in sentence)
#
# logical operators
#
# if else:
# c = np.array([1, 2, 3])
#
# c_sum = np.sum(c)
#
# if c_sum >= 5:
#     print("The sum is greater than or equal to 5")
# else:
#     print("It is strictly less than 5")
#
# exercises:  booleans, boolean with bar plot color, else if with sum value, string boolean, password check, append, test a number interval,

# %% [markdown]
# Lecture 6:
# bar graph:
# categories = ["Freshman", "Sophomore", "Junior", "Senior"]
# num_students = [22, 21, 31, 25]
#
# plt.bar(x = categories, height = num_students)
# plt.ylabel("Number registered")
# plt.title("DATASCI 151 - Spring 2026 students")
# plt.show()
#
# numpy arrays(adds elements of two sequences entry by entry):
# list_of_numbers = [5.6, 2.9, 9.7, -10, 0, 3]
#
# array_of_numbers = np.array(list_of_numbers)
#
# print(type(array_of_numbers))
# print(array_of_numbers)
# display(array_of_numbers)
#
# or
# a = np.array([3, 11, -2.2])
# print(a + 2)
#
# using np for math:
# print(np.log(2))
# print(np.exp(2))
# print(np.sin(2))
# print(np.cos(2))
# print(np.sqrt(2))
#
# exercises: concatonate, bar graph, math, numpy arrays

# %% [markdown]
# Lecture 5:
# tuples- immutable- can't change
# lists- mutable, can change
#
# Concatenation:
# list_1 = [2, 3, 5, 11]
# list_2 = [1, -4, 2, 0]
#
# list_3 = list_1 + list_2

# %% [markdown]
# Lecture 4:
# objects(integers, float, strings)
# variable: x=3 print(x)
# calculating things with variables (simple)
# intro to lists
# favorite_movies = ["Rear Window", "Inception", "Dead Poet Society", "Baby Driver", "Evil Dead (2013 remake)"]j
# print(type(favorite_movies))
# len length function
# print(favorite_movies[0]) # print the first element (element zero)
# index:
# alec_ind = 2
#
# print(favorite_movies[alec_ind])
#
# alec_fav_movie = favorite_movies[alec_ind]
# print(alec_fav_movie)

# %% [markdown]
# Lecture 2:
# print("")
# import math
# import statistics as stats
# import matplotlib.pyplot as plt
# import pandas as pd
#
# carfeatures = pd.read_csv("data/features.csv")
#
# Explains showing the data/columns
#
# Scatterplot:
# plt.scatter(x = carfeatures['weight'], y = carfeatures['mpg'])
# plt.xlabel("Weight")
# plt.ylabel("MPG")
# plt.title("Relationship between weight \n and gas mileage of automobiles") # \n means "new line"
# plt.show()

# %% [markdown]
# Lecture 1:
# to change font:
# <font size="">
